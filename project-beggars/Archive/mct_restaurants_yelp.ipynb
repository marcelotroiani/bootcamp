# %%
# Dependencies
import requests
import json
import pandas as pd
import gmaps
from yelpapi import YelpAPI

# Google API Key
from config import google_key
from config import yelp_key
yelp_api = YelpAPI(yelp_key)

# %%
store_locations = pd.read_csv("Resources/projectbeggarsstart_geo.csv")
store_locations
# Out:
#     SQL_ID               Address              City State   Latitude  Longitude
# 0      122       12700 S Kedzie        Blue Island    IL  41.661707 -87.700403
# 1      123       12660 S Western       Blue Island    IL  41.663078 -87.680465
# 2    10465       3277 W 115th St  Merrionette Park    IL  41.683913 -87.701136
# 3    11834   22149 Governors Hwy      Richton Park    IL  41.485875 -87.712412
# 4    10674       3524 Ridge Road           Lansing    IL  41.564555 -87.531317
# 5    10766   15600 S Cicero Road        Oak Forest    IL  41.608535 -87.737192
# 6    10783     650 W Lincoln Hwy         New Lenox    IL  41.518236 -87.981932
# 7    12294    11329 W. 143rd St.       Orland Park    IL  41.629047 -87.896268
# 8    12340      310 S Clinton St           Chicago    IL  41.877560 -87.641331
# 9    12896        165 Main St NW       Bourbonnais    IL  41.155617 -87.880621
# 10   14383           417 63rd St    Downers Grove     IL  41.772705 -87.994602
# 11   12086    10314 S Halsted St           Chicago    IL  41.706408 -87.643237
# 12   13604    621 W Roosevelt Rd           Maywood    IL  41.864653 -87.840603
# 13   10688   10240 S Central Ave         Oak Lawn     IL  41.706011 -87.760370
# 14   11467          3344 Hart St              Dyer    IN  41.471215 -87.518912
# 15   11549      1640 E Summit St       Crown Point    IN  41.428878 -87.337822
# 16   12168       369 Sibley Blvd            Harvey    IL  41.622626 -87.634157
# 17   12359     8100 Stony Island           Chicago    IL  41.747549 -87.586346
# 18   12601       5133 Cicero Ave           Chicago    IL  41.799507 -87.742692
# 19   13289     10685 Randolph St         Winfield     IN  41.423694 -87.238425
# 20   13210         1326 119th St           Whiting    IN  41.679099 -87.496528
# 21   11409      16122 S Route 59        Plainfield    IL  41.589166 -88.202326
# 22   10584       9515 W 191st St            Mokena    IL  41.542526 -87.848635
# 23   14593      3518 Calumet Ave        Valparaiso    IN  41.500326 -87.041481
# 24   14581  300 Veterans Parkway       Bolingbrook    IL  41.689456 -88.116668

# %%
search_results = yelp_api.search_query(latitude=41.661707,longitude=-87.700403,categories="restaurants",radius=2000,limit=50)

# %%
len(search_results["businesses"])
# Out:
# 13

# %%
# parameters
target_categories = "restaurants"
target_radius = 2000
target_limit = 50

ID = []
name = []
rating = []
review_count = []
lat = []
lng = []
transactions = []
distance = []
category = []

for index, row in store_locations.iterrows():

    target_id = row["SQL_ID"]

    # Search Yelp
    search_results = yelp_api.search_query(latitude=row["Latitude"],longitude=row["Longitude"],categories=target_categories,radius=target_radius,limit=target_limit)

    for result in search_results["businesses"]:
        if "Beggar" not in result["name"]:
            ID.append(target_id)
            rating.append(result["rating"])
            review_count.append(result["review_count"])
            name.append(result["name"])
            lat.append(result["coordinates"]["latitude"])
            lng.append(result["coordinates"]["longitude"])
            transactions.append(result["transactions"])
            distance.append(result["distance"])
            category.append(result["categories"][0]["title"])

# %%
#print(json.dumps(places_data, indent=4, sort_keys=True))
#print(len(places_data["results"]))
places = pd.DataFrame({
    "ID" : ID,
    "Name" : name,
    "Category" : category,
    "Review Count" : review_count,
    "Rating" : rating,
    "Transactions" : transactions,
    "Distance" : distance,
    "Latitude" : lat,
    "Longitude" : lng
})
places.to_csv("Resources/restaurants_yelp.csv", index=False)
places
# Out:
#         ID                               Name                Category  \
# 0      122               Pilich Station Grill  American (Traditional)
# 1      122                 115 Bourbon Street             Sports Bars
# 2      122                Chicago Curry House                  Indian
# 3      122                 Isaac's Restaurant           Chicken Wings
# 4      122                 Wings China Palace                 Chinese
# 5      122                  Da Portable Rican             Food Trucks
# 6      122                             Arby's               Fast Food
# 7      122                      Mr. Submarine              Sandwiches
# 8      122                             Subway               Fast Food
# 9      122  Original Maxwell Street South Inc               Fast Food
# 10     122                      The Bait Shop             Food Trucks
# 11     123               Pilich Station Grill  American (Traditional)
# 12     123                        T & G Gyros                   Greek
# 13     123                  La Vieja Castilla                 Spanish
# 14     123                 Mariscos La Sirena                 Mexican
# 15     123                   Giuseppe's Pizza                   Pizza
# 16     123               Tuscan Grill & Pizza                 Italian
# 17     123                    Love On the Blu                    Bars
# 18     123               De Mar's  Restaurant  American (Traditional)
# 19     123                Blue Island Seafood                 Seafood
# 20     123            Lumes House of Pancakes      Breakfast & Brunch
# 21     123        Taqueria Durango Restaurant                 Mexican
# 22     123           Restaurante Tenochtitlan                 Mexican
# 23     123                      Mario's Tacos                 Mexican
# 24     123                           Eggshack      Breakfast & Brunch
# 25     123                       Mr Chop Suey                 Chinese
# 26     123                Chicago Curry House                  Indian
# 27     123                   Birrieria Loreto                 Mexican
# 28     123                   Harry's Long Bar             Steakhouses
# 29     123                       Pollo Locuas                 Mexican
# ..     ...                                ...                     ...
# 879  14581        Buona Restaurant & Catering                 Italian
# 880  14581             Lou Malnati's Pizzeria                   Pizza
# 881  14581                        Chick-fil-A               Fast Food
# 882  14581                          Zen House                 Chinese
# 883  14581          Red Robin Gourmet Burgers                 Burgers
# 884  14581             Chipotle Mexican Grill                 Mexican
# 885  14581                     Casa Margarita                 Mexican
# 886  14581                          Pita Zone           Mediterranean
# 887  14581               Charlie's Restaurant  American (Traditional)
# 888  14581    Olive Garden Italian Restaurant                 Italian
# 889  14581                       Penn Station              Sandwiches
# 890  14581       Osaka Grill & Supreme Buffet                 Buffets
# 891  14581                  Noodles & Company                 Noodles
# 892  14581                        Red Lobster                 Seafood
# 893  14581                            Chili's  American (Traditional)
# 894  14581                 Jersey Mike's Subs              Sandwiches
# 895  14581     Salerno's Pizza of Bolingbrook                   Pizza
# 896  14581                      Nancy's Pizza                   Pizza
# 897  14581                     Firehouse Subs              Sandwiches
# 898  14581                      Panda Express                 Chinese
# 899  14581                       Panera Bread              Sandwiches
# 900  14581                     Steak 'n Shake                 Burgers
# 901  14581                                KFC               Fast Food
# 902  14581                       Jimmy John's              Sandwiches
# 903  14581                         McDonald's               Fast Food
# 904  14581                        Burger King               Fast Food
# 905  14581                            Wendy's                 Burgers
# 906  14581                             Subway              Sandwiches
# 907  14581                             Subway              Sandwiches
# 908  14581                       Jimmy John's              Sandwiches
#
#      Review Count  Rating        Transactions      Distance   Latitude  \
# 0              81     5.0                  []    471.434322  41.661957
# 1             203     3.0                  []   2407.051861  41.684069
# 2             553     3.5  [pickup, delivery]  24008.163309  41.870860
# 3              10     4.0  [pickup, delivery]    143.454144  41.662690
# 4              22     3.5                  []   2414.264293  41.684092
# 5              42     4.5                  []  44444.956788  41.578094
# 6               7     1.5                  []    172.001619  41.663202
# 7               7     1.5                  []    443.632410  41.662700
# 8               4     2.5                  []   2494.766110  41.684091
# 9               2     2.5                  []   2193.639247  41.647151
# 10              1     4.0                  []   9483.339800  41.625220
# 11             81     5.0                  []   1192.191632  41.661957
# 12             45     4.5                  []    669.861930  41.657067
# 13             26     4.5                  []    734.740693  41.656487
# 14             50     4.0                  []   1175.477508  41.655918
# 15             41     4.5                  []   1452.803298  41.650014
# 16             39     4.0                  []    672.132435  41.657036
# 17             80     3.0                  []    383.844964  41.666588
# 18             21     4.5                  []    577.129266  41.657901
# 19             28     4.0                  []    140.440701  41.664600
# 20             83     4.0                  []   2146.036151  41.682378
# 21             42     3.5                  []    581.086976  41.668302
# 22             52     3.5  [delivery, pickup]    605.191707  41.657650
# 23             86     3.5                  []   1374.505199  41.650661
# 24             28     4.0                  []   1341.685192  41.662570
# 25             21     4.0  [delivery, pickup]    805.731537  41.670370
# 26            553     3.5  [delivery, pickup]  23500.853844  41.870860
# 27              6     4.5                  []    779.090550  41.670067
# 28             12     3.5                  []    904.376260  41.654956
# 29             25     3.0                  []    796.936014  41.670226
# ..            ...     ...                 ...           ...        ...
# 879            73     4.0  [delivery, pickup]    817.041667  41.689125
# 880            51     4.0  [delivery, pickup]    822.704008  41.691007
# 881            59     4.0                  []   1572.885966  41.701892
# 882            38     4.0                  []    893.916958  41.689310
# 883            90     3.0  [delivery, pickup]    570.599985  41.692249
# 884            44     3.5                  []    714.473810  41.690632
# 885           218     2.5                  []    921.076618  41.696210
# 886            39     4.0                  []   1132.751868  41.682874
# 887            42     3.5                  []   1186.031830  41.695823
# 888            95     2.5                  []    711.144190  41.692719
# 889            70     3.0                  []    760.857142  41.689846
# 890           107     2.5                  []    915.357612  41.695257
# 891            60     3.0                  []   1240.737936  41.698784
# 892            47     2.5  [delivery, pickup]    692.071113  41.693240
# 893            51     3.0                  []   1601.490412  41.702580
# 894            36     3.0            [pickup]   1507.754598  41.701752
# 895            62     3.0  [delivery, pickup]   2459.150121  41.668510
# 896            32     3.0                  []   1512.071110  41.701805
# 897            33     3.0            [pickup]   1559.807794  41.702860
# 898            21     3.0                  []   1404.414958  41.700466
# 899            27     3.0                  []   1812.305602  41.705050
# 900            54     2.0            [pickup]   1143.742763  41.698302
# 901            15     1.5          [delivery]    703.310018  41.692200
# 902            22     2.0                  []   1640.865952  41.703377
# 903            28     2.0                  []   1850.047735  41.704321
# 904             9     2.0          [delivery]   1644.380576  41.703900
# 905             6     1.5                  []    747.409578  41.692364
# 906             3     2.5                  []   1123.011876  41.683020
# 907             2     4.5                  []   1935.172671  41.705111
# 908             8     2.5                  []   1681.872816  41.703748
#
#      Longitude
# 0   -87.694738
# 1   -87.704797
# 2   -87.628460
# 3   -87.699340
# 4   -87.703626
# 5   -87.177559
# 6   -87.700936
# 7   -87.695182
# 8   -87.703784
# 9   -87.718224
# 10  -87.587250
# 11  -87.694738
# 12  -87.679932
# 13  -87.679853
# 14  -87.670104
# 15  -87.680680
# 16  -87.680244
# 17  -87.680425
# 18  -87.679977
# 19  -87.679880
# 20  -87.680579
# 21  -87.680649
# 22  -87.679944
# 23  -87.680428
# 24  -87.664180
# 25  -87.679960
# 26  -87.628460
# 27  -87.679788
# 28  -87.679906
# 29  -87.679759
# ..         ...
# 879 -88.126498
# 880 -88.126356
# 881 -88.125696
# 882 -88.127410
# 883 -88.122337
# 884 -88.125603
# 885 -88.123060
# 886 -88.127080
# 887 -88.128129
# 888 -88.123962
# 889 -88.125816
# 890 -88.124490
# 891 -88.124869
# 892 -88.123240
# 893 -88.124614
# 894 -88.124323
# 895 -88.126172
# 896 -88.124290
# 897 -88.122680
# 898 -88.124957
# 899 -88.123017
# 900 -88.123698
# 901 -88.124300
# 902 -88.123108
# 903 -88.126678
# 904 -88.120440
# 905 -88.124786
# 906 -88.126990
# 907 -88.126342
# 908 -88.123301
#
# [909 rows x 9 columns]

# %%
gmaps.configure(api_key=google_key)
locations_beggars = store_locations[["Latitude", "Longitude"]].astype(float)
locations_others = places[["Latitude", "Longitude"]].astype(float)

# %%
fig = gmaps.figure()
beggars_layer = gmaps.symbol_layer(
    locations_beggars, fill_color='blue', stroke_color='blue', scale=4
)
others_layer = gmaps.symbol_layer(
    locations_others, fill_color='red', stroke_color='red', scale=2
)

fig.add_layer(beggars_layer)
fig.add_layer(others_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
